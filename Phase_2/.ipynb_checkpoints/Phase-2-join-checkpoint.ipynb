# %%
import numpy as np
import pandas as pd
import datetime as dt

# %%
# import dataset
crimes = pd.read_csv("crimes_python_clean.csv", encoding='latin-1', engine='python')
off_codes = pd.read_csv("offense_codes.csv", encoding='latin-1', engine='python')

# %%
crimes.head()
# Out:
#    incident_id         offense_id  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0  20226000193  20226000193299900          2999                       0
# 1     20223319     20223319299900          2999                       0
# 2     20223093     20223093299900          2999                       0
# 3     20224000     20224000299900          2999                       0
# 4     20223956     20223956299900          2999                       0
#
#        GEO_X      GEO_Y     GEO_LON    GEO_LAT  DISTRICT_ID  PRECINCT_ID  ...  \
# 0  3135366.0  1685410.0 -105.018825  39.714268          4.0        411.0  ...
# 1  3142454.0  1696151.0 -104.993418  39.743649          6.0        611.0  ...
# 2  3147484.0  1694898.0 -104.975557  39.740130          6.0        621.0  ...
# 3  3136478.0  1684414.0 -105.014892  39.711518          4.0        411.0  ...
# 4  3169237.0  1705800.0 -104.897950  39.769688          5.0        512.0  ...
#
#    first_occurrence_date_dt  first_occurrence_date_isoformat  \
# 0       2022-01-04 11:30:00              2022-01-04T11:30:00
# 1       2022-01-03 06:45:00              2022-01-03T06:45:00
# 2       2022-01-03 01:00:00              2022-01-03T01:00:00
# 3       2022-01-03 19:47:00              2022-01-03T19:47:00
# 4       2022-01-03 17:06:00              2022-01-03T17:06:00
#
#       reported_date_dt reported_date_isoformat     OFFENSE_TYPE_ID_trim  \
# 0  2022-01-04 20:36:00     2022-01-04T20:36:00  criminal-mischief-other
# 1  2022-01-03 11:01:00     2022-01-03T11:01:00  criminal-mischief-other
# 2  2022-01-03 06:11:00     2022-01-03T06:11:00  criminal-mischief-other
# 3  2022-01-03 21:12:00     2022-01-03T21:12:00  criminal-mischief-other
# 4  2022-01-03 20:31:00     2022-01-03T20:31:00  criminal-mischief-other
#
#   OFFENSE_CATEGORY_ID_trim     INCIDENT_STREET       NEIGHBORHOOD_ID_trim  \
# 0          public-disorder     128 S CANOSA CT                   valverde
# 1          public-disorder         650 15TH ST  central-business-district
# 2          public-disorder    919 E COLFAX AVE         north-capitol-hill
# 3          public-disorder  2345 W ALAMEDA AVE                   valverde
# 4          public-disorder     7800 E SMITH RD               central-park
#
#         nearest_neighborhood nearest_neighborhood_dist_km
# 0                   valverde                          0.0
# 1  central-business-district                          0.0
# 2         north-capitol-hill                          0.0
# 3                   valverde                          0.0
# 4               central-park                          0.0
#
# [5 rows x 23 columns]

# %%
off_codes.head()
# Out:
#    OBJECTID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0         1          2804                       1
# 1         2          2804                       2
# 2         3          2901                       0
# 3         4          2902                       0
# 4         5          2903                       0
#
#                   OFFENSE_TYPE_ID                      OFFENSE_TYPE_NAME  \
# 0      stolen-property-possession          Possession of stolen property
# 1  fraud-possess-financial-device       Possession of a financial device
# 2                damaged-prop-bus              Damaged business property
# 3       criminal-mischief-private  Criminal mischief to private property
# 4        criminal-mischief-public   Criminal mischief to public property
#
#   OFFENSE_CATEGORY_ID OFFENSE_CATEGORY_NAME  IS_CRIME  IS_TRAFFIC
# 0    all-other-crimes      All Other Crimes         1           0
# 1    all-other-crimes      All Other Crimes         1           0
# 2     public-disorder       Public Disorder         1           0
# 3     public-disorder       Public Disorder         1           0
# 4     public-disorder       Public Disorder         1           0

# %%
#join table
crimes = crimes.merge(off_codes, on=['OFFENSE_CODE','OFFENSE_CODE_EXTENSION'],how='left')

# %%
list(crimes)
# Out:
# ['incident_id',
#  'offense_id',
#  'OFFENSE_CODE',
#  'OFFENSE_CODE_EXTENSION',
#  'GEO_X',
#  'GEO_Y',
#  'GEO_LON',
#  'GEO_LAT',
#  'DISTRICT_ID',
#  'PRECINCT_ID',
#  'IS_CRIME_x',
#  'IS_TRAFFIC_x',
#  'VICTIM_COUNT',
#  'first_occurrence_date_dt',
#  'first_occurrence_date_isoformat',
#  'reported_date_dt',
#  'reported_date_isoformat',
#  'OFFENSE_TYPE_ID_trim',
#  'OFFENSE_CATEGORY_ID_trim',
#  'INCIDENT_STREET',
#  'NEIGHBORHOOD_ID_trim',
#  'nearest_neighborhood',
#  'nearest_neighborhood_dist_km',
#  'OBJECTID',
#  'OFFENSE_TYPE_ID',
#  'OFFENSE_TYPE_NAME',
#  'OFFENSE_CATEGORY_ID',
#  'OFFENSE_CATEGORY_NAME',
#  'IS_CRIME_y',
#  'IS_TRAFFIC_y']

# %%
#check that IS_CRIME_x', 'IS_TRAFFIC_x', is equal to 'IS_CRIME_y','IS_TRAFFIC_y'
duplicate_list = ['IS_CRIME', 'IS_TRAFFIC']

for duplicate in duplicate_list:
    pd.testing.assert_series_equal(crimes[duplicate+'_x'],crimes[duplicate+'_y'],check_names=False)

# %%
# drop redunant columns/ columns we don't need
# not totally sure if we wanna drop these since the name is the same? - 'OFFENSE_TYPE_ID','OFFENSE_CATEGORY_ID'

columns_to_drop = [
    'GEO_X',
    'GEO_Y', 'DISTRICT_ID',
    'nearest_neighborhood_dist_km',
    'OBJECTID',
    'OFFENSE_TYPE_ID',
    'OFFENSE_CATEGORY_ID',
    'IS_CRIME_y',
    'IS_TRAFFIC_y',
    'first_occurrence_date_dt',
    'reported_date_dt',
    'OFFENSE_TYPE_ID_trim',
    'OFFENSE_CATEGORY_ID_trim'
]
crimes = crimes.drop(columns = columns_to_drop)

# %%
list(crimes)
# Out:
# ['incident_id',
#  'offense_id',
#  'OFFENSE_CODE',
#  'OFFENSE_CODE_EXTENSION',
#  'GEO_LON',
#  'GEO_LAT',
#  'PRECINCT_ID',
#  'IS_CRIME_x',
#  'IS_TRAFFIC_x',
#  'VICTIM_COUNT',
#  'first_occurrence_date_isoformat',
#  'reported_date_isoformat',
#  'INCIDENT_STREET',
#  'NEIGHBORHOOD_ID_trim',
#  'nearest_neighborhood',
#  'OFFENSE_TYPE_NAME',
#  'OFFENSE_CATEGORY_NAME']

# %%
#make column names lowercase 
crimes.columns = [x.lower() for x in crimes.columns]

# %%
list(crimes)
# Out:
# ['incident_id',
#  'offense_id',
#  'offense_code',
#  'offense_code_extension',
#  'geo_lon',
#  'geo_lat',
#  'precinct_id',
#  'is_crime_x',
#  'is_traffic_x',
#  'victim_count',
#  'first_occurrence_date_isoformat',
#  'reported_date_isoformat',
#  'incident_street',
#  'neighborhood_id_trim',
#  'nearest_neighborhood',
#  'offense_type_name',
#  'offense_category_name']

# %%
crimes.rename(columns = {
    'is_crime_x':'is_crime',
    'is_traffic_x':'is_traffic',
    'first_occurrence_date_isoformat':'first_occurrence_date',
    'reported_date_isoformat':'reported_date',
    'neighborhood_id_trim':'neighborhood_id'
}, inplace = True)

# %%
list(crimes)
# Out:
# ['incident_id',
#  'offense_id',
#  'offense_code',
#  'offense_code_extension',
#  'geo_lon',
#  'geo_lat',
#  'precinct_id',
#  'is_crime',
#  'is_traffic',
#  'victim_count',
#  'first_occurrence_date',
#  'reported_date',
#  'incident_street',
#  'neighborhood_id',
#  'nearest_neighborhood',
#  'offense_type_name',
#  'offense_category_name']

# %%
crimes.head()
# Out:
#    incident_id         offense_id  offense_code  offense_code_extension  \
# 0  20226000193  20226000193299900          2999                       0
# 1     20223319     20223319299900          2999                       0
# 2     20223093     20223093299900          2999                       0
# 3     20224000     20224000299900          2999                       0
# 4     20223956     20223956299900          2999                       0
#
#       geo_lon    geo_lat  precinct_id  is_crime  is_traffic  victim_count  \
# 0 -105.018825  39.714268        411.0         1           0             1
# 1 -104.993418  39.743649        611.0         1           0             1
# 2 -104.975557  39.740130        621.0         1           0             1
# 3 -105.014892  39.711518        411.0         1           0             1
# 4 -104.897950  39.769688        512.0         1           0             1
#
#   first_occurrence_date        reported_date     incident_street  \
# 0   2022-01-04T11:30:00  2022-01-04T20:36:00     128 S CANOSA CT
# 1   2022-01-03T06:45:00  2022-01-03T11:01:00         650 15TH ST
# 2   2022-01-03T01:00:00  2022-01-03T06:11:00    919 E COLFAX AVE
# 3   2022-01-03T19:47:00  2022-01-03T21:12:00  2345 W ALAMEDA AVE
# 4   2022-01-03T17:06:00  2022-01-03T20:31:00     7800 E SMITH RD
#
#              neighborhood_id       nearest_neighborhood  \
# 0                   valverde                   valverde
# 1  central-business-district  central-business-district
# 2         north-capitol-hill         north-capitol-hill
# 3                   valverde                   valverde
# 4               central-park               central-park
#
#            offense_type_name offense_category_name
# 0  Criminal mischief - other       Public Disorder
# 1  Criminal mischief - other       Public Disorder
# 2  Criminal mischief - other       Public Disorder
# 3  Criminal mischief - other       Public Disorder
# 4  Criminal mischief - other       Public Disorder

# %%
#TODO: check integrity constraints 
#primary key is the incident_id and offense_id since an incident can have multiple offenses 
primary_key_violations = crimes[crimes.duplicated(subset=['incident_id','offense_id'], keep=False)]

# %%
primary_key_violations
# Out:
# Empty DataFrame
# Columns: [incident_id, offense_id, offense_code, offense_code_extension, geo_lon, geo_lat, precinct_id, is_crime, is_traffic, victim_count, first_occurrence_date, reported_date, incident_street, neighborhood_id, nearest_neighborhood, offense_type_name, offense_category_name]
# Index: []

# %%
#save clean data to csv
#crimes.to_csv('crimes_tables_join_clean.csv', index=False)

# %%
#split tables according to the date year and save into diff tables
